# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\flytr\Downloads\PFAS_Stats_Final_Df.csv")

# %%
df = df[['location',
 'latitude',
 'longitude',
 'value',
 'N_D_MINOR_PER_Q1',
 'N_D_INCOME_PER_Q1',
 'N_D_LESSHS_PER_Q1',
 'N_D_UNEMPLOYED_PER_Q1',
 'N_D_INDEX_PER_Q1',
 'N_D_MINOR_PER_Q3',
 'N_D_INCOME_PER_Q3',
 'N_D_LESSHS_PER_Q3',
 'N_D_UNEMPLOYED_PER_Q3',
 'N_D_INDEX_PER_Q3',
 'N_D_MINOR_PER_MIN',
 'N_D_INCOME_PER_MIN',
 'N_D_LESSHS_PER_MIN',
 'N_D_UNEMPLOYED_PER_MIN',
 'N_D_INDEX_PER_MIN',
 'N_D_MINOR_PER_MAX',
 'N_D_INCOME_PER_MAX',
 'N_D_LESSHS_PER_MAX',
 'N_D_UNEMPLOYED_PER_MAX',
 'N_D_INDEX_PER_MAX',
 'N_D_MINOR_PER_MEDIAN',
 'N_D_INCOME_PER_MEDIAN',
 'N_D_LESSHS_PER_MEDIAN',
 'N_D_UNEMPLOYED_PER_MEDIAN',
 'N_D_INDEX_PER_MEDIAN',
 'N_D_MINOR_PER_MEAN',
 'N_D_INCOME_PER_MEAN',
 'N_D_LESSHS_PER_MEAN',
 'N_D_UNEMPLOYED_PER_MEAN',
 'N_D_INDEX_PER_MEAN',
 'N_D_MINOR_PER_VAR',
 'N_D_INCOME_PER_VAR',
 'N_D_LESSHS_PER_VAR',
 'N_D_UNEMPLOYED_PER_VAR',
 'N_D_INDEX_PER_VAR',
 'N_D_MINOR_PER_STD',
 'N_D_INCOME_PER_STD',
 'N_D_LESSHS_PER_STD',
 'N_D_UNEMPLOYED_PER_STD',
 'N_D_INDEX_PER_STD',
 'N_D_MINOR_PER_SUM',
 'N_D_INCOME_PER_SUM',
 'N_D_LESSHS_PER_SUM',
 'N_D_UNEMPLOYED_PER_SUM',
 'N_D_INDEX_PER_SUM',
 'N_D_MINOR_PER_N',
 'N_D_INCOME_PER_N',
 'N_D_LESSHS_PER_N',
 'N_D_UNEMPLOYED_PER_N',
 'N_D_INDEX_PER_N',
 'totalPop_N']]

# %%
df.head()
# Out:
#                location   latitude  longitude  value  N_D_MINOR_PER_Q1  \
# 0  USGS-322658085465001  32.449306 -85.779667    0.0              82.0
# 1  USGS-323908086360201  32.651861 -86.600694    0.0              39.0
# 2  USGS-325159086423801  32.866500 -86.710528    0.0              18.0
# 3  USGS-332630087430001  33.442611 -87.714722    0.0               5.0
# 4  USGS-332833086203001  33.475940 -86.341645    0.0              17.0
#
#    N_D_INCOME_PER_Q1  N_D_LESSHS_PER_Q1  N_D_UNEMPLOYED_PER_Q1  \
# 0               41.0               59.0                   75.0
# 1               62.0               68.0                   54.0
# 2               74.0               70.0                   39.0
# 3               21.0               48.0                    0.0
# 4               58.0               48.0                    0.0
#
#    N_D_INDEX_PER_Q1  N_D_MINOR_PER_Q3  ...  N_D_INCOME_PER_SUM  \
# 0              78.0              86.0  ...              1186.0
# ...

# %%
df = df[[
 'location',
 'latitude',
 'longitude',
 'value',
 'N_D_MINOR_PER_MEAN',
 'N_D_INCOME_PER_MEAN',
 'N_D_LESSHS_PER_MEAN',
 'N_D_UNEMPLOYED_PER_MEAN',
 'N_D_INDEX_PER_MEAN',
 ]]

# %%
df.head()
# Out:
#                location   latitude  longitude  value  N_D_MINOR_PER_MEAN  \
# 0  USGS-322658085465001  32.449306 -85.779667    0.0            83.52381
# 1  USGS-323908086360201  32.651861 -86.600694    0.0            39.00000
# 2  USGS-325159086423801  32.866500 -86.710528    0.0            25.47619
# 3  USGS-332630087430001  33.442611 -87.714722    0.0             5.00000
# 4  USGS-332833086203001  33.475940 -86.341645    0.0            15.76000
#
#    N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  N_D_UNEMPLOYED_PER_MEAN  \
# 0            56.476190            60.238095                86.761905
# 1            62.000000            68.000000                54.000000
# 2            71.714286            66.333333                36.333333
# 3            21.000000            48.000000                 0.000000
# 4            56.240000            51.480000                18.320000
#
#    N_D_INDEX_PER_MEAN
# 0           79.857143
# 1           48.000000
# 2           46.380952
# ...

# %%
# Out:
# It contains 0 infinite values

# %%
# df = df.sort_values('value')

# %%
#This contains the location data in the same order as the rest of the file
locationData = df[['location','latitude','longitude']]

# %%
df = df[[
 'value',
 'N_D_MINOR_PER_MEAN',
 'N_D_INCOME_PER_MEAN',
 'N_D_LESSHS_PER_MEAN',
 'N_D_UNEMPLOYED_PER_MEAN',
 'N_D_INDEX_PER_MEAN',
 ]]

# %%
df.head()
# Out:
#    value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  \
# 0    0.0            83.52381            56.476190            60.238095
# 1    0.0            39.00000            62.000000            68.000000
# 2    0.0            25.47619            71.714286            66.333333
# 3    0.0             5.00000            21.000000            48.000000
# 4    0.0            15.76000            56.240000            51.480000
#
#    N_D_UNEMPLOYED_PER_MEAN  N_D_INDEX_PER_MEAN
# 0                86.761905           79.857143
# 1                54.000000           48.000000
# 2                36.333333           46.380952
# 3                 0.000000            5.000000
# 4                18.320000           29.600000

# %%
quart = 9.235
med = 29.760
upper = 83.750

# %%
# df.loc[df['value'] > upper, 'value'] = 4
# df.head()
df.loc[df['value'] < quart, 'value'] = 1
df.head()
# Out:
#    value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  \
# 0    1.0            83.52381            56.476190            60.238095
# 1    1.0            39.00000            62.000000            68.000000
# 2    1.0            25.47619            71.714286            66.333333
# 3    1.0             5.00000            21.000000            48.000000
# 4    1.0            15.76000            56.240000            51.480000
#
#    N_D_UNEMPLOYED_PER_MEAN  N_D_INDEX_PER_MEAN
# 0                86.761905           79.857143
# 1                54.000000           48.000000
# 2                36.333333           46.380952
# 3                 0.000000            5.000000
# 4                18.320000           29.600000

# %%
df.loc[(df['value'] >= quart) & (df['value'] <= med), 'value'] = 2
df.head()
# Out:
#    value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  \
# 0    1.0            83.52381            56.476190            60.238095
# 1    1.0            39.00000            62.000000            68.000000
# 2    1.0            25.47619            71.714286            66.333333
# 3    1.0             5.00000            21.000000            48.000000
# 4    1.0            15.76000            56.240000            51.480000
#
#    N_D_UNEMPLOYED_PER_MEAN  N_D_INDEX_PER_MEAN
# 0                86.761905           79.857143
# 1                54.000000           48.000000
# 2                36.333333           46.380952
# 3                 0.000000            5.000000
# 4                18.320000           29.600000

# %%
df.loc[(df['value'] >= med) & (df['value'] <= upper), 'value'] = 3
df
# Out:
#         value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  \
# 0       1.000           83.523810            56.476190            60.238095
# 1       1.000           39.000000            62.000000            68.000000
# 2       1.000           25.476190            71.714286            66.333333
# 3       1.000            5.000000            21.000000            48.000000
# 4       1.000           15.760000            56.240000            51.480000
# 5       1.000           34.523810            42.714286            70.142857
# 6       1.000           29.521739            15.782609            11.956522
# 7       1.000           61.285714            75.142857            72.357143
# 8       1.000           57.363636            11.454545            44.363636
# 9       1.000           82.000000            85.000000            88.000000
# 10      1.000           60.416667            23.125000            29.041667
# ...

# %%
df.loc[df['value'] > upper,'value'] = 4

# %%
#OFFICIAL FINAL MAIN DF w/ QUARTILES

# %%
df.describe()
# Out:
#              value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  \
# count  2332.000000         2242.000000          2242.000000
# mean      1.238422           39.804256            46.590953
# std       0.707088           23.951402            21.564340
# min       1.000000            0.000000             1.200000
# 25%       1.000000           19.045109            29.090000
# 50%       1.000000           36.604779            46.803828
# 75%       1.000000           57.917917            62.880000
# max       4.000000           99.000000            97.300000
#
#        N_D_LESSHS_PER_MEAN  N_D_UNEMPLOYED_PER_MEAN  N_D_INDEX_PER_MEAN
# count          2242.000000              2242.000000         2242.000000
# mean             49.672641                49.455270           40.740277
# std              22.728793                22.195139           23.157665
# min               0.000000                 0.000000            1.545455
# ...

# %%
df.dropna()
df.head()
# Out:
#    value  N_D_MINOR_PER_MEAN  N_D_INCOME_PER_MEAN  N_D_LESSHS_PER_MEAN  \
# 0    1.0            83.52381            56.476190            60.238095
# 1    1.0            39.00000            62.000000            68.000000
# 2    1.0            25.47619            71.714286            66.333333
# 3    1.0             5.00000            21.000000            48.000000
# 4    1.0            15.76000            56.240000            51.480000
#
#    N_D_UNEMPLOYED_PER_MEAN  N_D_INDEX_PER_MEAN
# 0                86.761905           79.857143
# 1                54.000000           48.000000
# 2                36.333333           46.380952
# 3                 0.000000            5.000000
# 4                18.320000           29.600000

# %%
df.rename(columns={'N_D_MINOR_PER_MEAN': 'MINOR_PER', 'N_D_INCOME_PER_MEAN': 'INCOME_PER','N_D_LESSHS_PER_MEAN': 'LESSHS_PER', 'N_D_UNEMPLOYED_PER_MEAN': 'UNEMPLOYED_PER','N_D_INDEX_PER_MEAN': 'INDEX_PER'}, inplace=True)
df.head()
# Out:
#    value  MINOR_PER  INCOME_PER  LESSHS_PER  UNEMPLOYED_PER  INDEX_PER
# 0    1.0   83.52381   56.476190   60.238095       86.761905  79.857143
# 1    1.0   39.00000   62.000000   68.000000       54.000000  48.000000
# 2    1.0   25.47619   71.714286   66.333333       36.333333  46.380952
# 3    1.0    5.00000   21.000000   48.000000        0.000000   5.000000
# 4    1.0   15.76000   56.240000   51.480000       18.320000  29.600000

# %%
X = df.loc[:,df.columns!="value"]
X.head()
# Out:
#    MINOR_PER  INCOME_PER  LESSHS_PER  UNEMPLOYED_PER  INDEX_PER
# 0   83.52381   56.476190   60.238095       86.761905  79.857143
# 1   39.00000   62.000000   68.000000       54.000000  48.000000
# 2   25.47619   71.714286   66.333333       36.333333  46.380952
# 3    5.00000   21.000000   48.000000        0.000000   5.000000
# 4   15.76000   56.240000   51.480000       18.320000  29.600000

# %%
y = df['value']
y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: value, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\flytr\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\utils\validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)

# %%
X_train = X_train.dropna()

# %%
# Out:
#       MINOR_PER  INCOME_PER  LESSHS_PER  UNEMPLOYED_PER  INDEX_PER
# 812       12.90   35.050000   55.350000       70.200000  14.500000
# 233       48.00   40.210526   45.684211       40.894737  42.684211
# 1380      30.36   53.920000   43.520000       62.360000  37.240000
# 1752       9.50   64.818182   62.954545       52.318182  33.045455
# 1334      47.04   17.680000   16.600000       44.920000  29.400000

# %%
#standardizing the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler().fit(X_train)

# %%
X_train_std = sc.transform(X_train)

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[ 0.27360951, -1.25064234, -0.17815569, -0.79937097, -0.4275938 ],
#        [-0.0131012 ,  0.08293104, -1.01768028,  0.42621747, -0.09703257],
#        [ 0.82850908, -0.31944795,  0.47252189, -1.06611296,  0.5873425 ],
#        ...,
#        [ 0.79235145, -0.85598122, -0.06418629, -0.47250146,  0.271573  ],
#        [ 0.66587542,  0.78942101, -0.12192079, -2.23739016,  0.81333746],
#        [-1.07483425,  0.47030152, -0.66427517,  1.10251704, -0.48106814]])

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
from sklearn import svm

# %%
rbf = svm.SVC(kernel='rbf',gamma = 0.5, C=0.1).fit(X_train_std,y_train)
poly = svm.SVC(kernel='poly',degrees=3, C=1).fit(X_train_std, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14872\4091665926.py in <module>
# ----> 1 rbf = svm.SVC(kernel='rbf',gamma = 0.5, C=0.1).fit(X_train_std,y_train)
#       2 poly = svm.SVC(kernel='poly',degrees=3, C=1).fit(X_train_std, y_train)
#
# ~\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ...
